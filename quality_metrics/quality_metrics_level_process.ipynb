# %% [markdown]
# # Quality Metrics Process

# %% [markdown]
# # UMTS CQI Processing

# %%
from umts_cqi_level_processor import (
    populate_umts_cqi_metrics_daily,
    get_last_date_umts_cqi_metrics_daily,
    get_last_date_umts_cqi_daily
)
from datetime import datetime, timedelta
"""
Main execution block for populating UMTS CQI metrics daily table.
"""
print("UMTS CQI Level Processor - Full Database Population")

try:
    # Get date ranges
    last_processed_date = get_last_date_umts_cqi_metrics_daily()
    latest_available_date = get_last_date_umts_cqi_daily()
    
    print(f"Last processed date in umts_cqi_metrics_daily: {last_processed_date}")
    print(f"Latest available date in umts_cqi_daily: {latest_available_date}")
    
    # Determine date range for processing
    if last_processed_date is None:
        print("No data found in umts_cqi_metrics_daily table. Starting from earliest available data.")
        # If no processed data exists, we'll start from a reasonable date
        # You might want to adjust this based on your data availability
        min_date = "2024-01-01"  # Adjust this to your earliest desired date
    else:
        # Start from the day after the last processed date
        last_date_obj = datetime.strptime(str(last_processed_date), '%Y-%m-%d')
        next_date_obj = last_date_obj + timedelta(days=1)
        min_date = next_date_obj.strftime('%Y-%m-%d')
    
    if latest_available_date is None:
        print("No data found in umts_cqi_daily table. Cannot process.")
        exit()
    
    max_date = str(latest_available_date)
    
    print(f"Processing date range: {min_date} to {max_date}")
    
    # Check if there's new data to process
    if min_date <= max_date:
        print(f"Starting population of umts_cqi_metrics_daily...")
        print(f"This will process all hierarchical levels: network, region, province, municipality, site")
        
        # Populate the database with all hierarchical levels
        populate_umts_cqi_metrics_daily(min_date, max_date)
        
        print("Processing completed successfully!")
        print(f"Data populated for all hierarchical levels from {min_date} to {max_date}")

        # Verify the update
        new_last_processed_date = get_last_date_umts_cqi_metrics_daily()
        print(f"New last processed date: {new_last_processed_date}")
        
    else:
        print("No new data to process. Database is up to date.")
        
except Exception as e:
    print(f"Error during execution: {e}")
    
    import traceback
    traceback.print_exc()
# Out:
# UMTS CQI Level Processor - Full Database Population
# Error during execution: Environment variable POSTGRES_PASSWORD is not set or is None
# Traceback (most recent call last):
#   File "/var/folders/7m/0x4sxfy511jfthqwv1f7rr640000gn/T/ipykernel_67626/1744717744.py", line 14, in <module>
#     last_processed_date = get_last_date_umts_cqi_metrics_daily()
#   File "/Users/alvaromolina/Downloads/RAN Quality Evaluator/quality_metrics/umts_cqi_level_processor.py", line 492, in get_last_date_umts_cqi_metrics_daily
#     engine = get_engine()
#   File "/Users/alvaromolina/Downloads/RAN Quality Evaluator/quality_metrics/umts_cqi_level_processor.py", line 29, in get_engine
#     raise ValueError(f"Environment variable {var_name} is not set or is None")
# ValueError: Environment variable POSTGRES_PASSWORD is not set or is None

# %% [markdown]
# # LTE CQI Processing

# %%
from lte_cqi_level_processor import (
    populate_lte_cqi_metrics_daily,
    get_last_date_lte_cqi_metrics_daily,
    get_last_date_lte_cqi_daily
)
from datetime import datetime, timedelta
"""
Main execution block for populating lte CQI metrics daily table.
"""
print("lte CQI Level Processor - Full Database Population")

try:
    # Get date ranges
    last_processed_date = get_last_date_lte_cqi_metrics_daily()
    latest_available_date = get_last_date_lte_cqi_daily()
    
    print(f"Last processed date in lte_cqi_metrics_daily: {last_processed_date}")
    print(f"Latest available date in lte_cqi_daily: {latest_available_date}")
    
    # Determine date range for processing
    if last_processed_date is None:
        print("No data found in lte_cqi_metrics_daily table. Starting from earliest available data.")
        # If no processed data exists, we'll start from a reasonable date
        # You might want to adjust this based on your data availability
        min_date = "2024-01-01"  # Adjust this to your earliest desired date
    else:
        # Start from the day after the last processed date
        last_date_obj = datetime.strptime(str(last_processed_date), '%Y-%m-%d')
        next_date_obj = last_date_obj + timedelta(days=1)
        min_date = next_date_obj.strftime('%Y-%m-%d')
    
    if latest_available_date is None:
        print("No data found in lte_cqi_daily table. Cannot process.")
        exit()
    
    max_date = str(latest_available_date)
    
    print(f"Processing date range: {min_date} to {max_date}")
    
    # Check if there's new data to process
    if min_date <= max_date:
        print(f"Starting population of lte_cqi_metrics_daily...")
        print(f"This will process all hierarchical levels: network, region, province, municipality, site")
        
        # Populate the database with all hierarchical levels
        populate_lte_cqi_metrics_daily(min_date, max_date)
        
        print("Processing completed successfully!")
        print(f"Data populated for all hierarchical levels from {min_date} to {max_date}")

        # Verify the update
        new_last_processed_date = get_last_date_lte_cqi_metrics_daily()
        print(f"New last processed date: {new_last_processed_date}")
        
    else:
        print("No new data to process. Database is up to date.")
        
except Exception as e:
    print(f"Error during execution: {e}")
    
    import traceback
    traceback.print_exc()
# Out:
# lte CQI Level Processor - Full Database Population
# Error during execution: Environment variable POSTGRES_PASSWORD is not set or is None
# Traceback (most recent call last):
#   File "/var/folders/7m/0x4sxfy511jfthqwv1f7rr640000gn/T/ipykernel_67626/1252781515.py", line 14, in <module>
#     last_processed_date = get_last_date_lte_cqi_metrics_daily()
#   File "/Users/alvaromolina/Downloads/RAN Quality Evaluator/quality_metrics/lte_cqi_level_processor.py", line 607, in get_last_date_lte_cqi_metrics_daily
#     engine = get_engine()
#   File "/Users/alvaromolina/Downloads/RAN Quality Evaluator/quality_metrics/lte_cqi_level_processor.py", line 29, in get_engine
#     #        raise ValueError(f"Environment variable {var_name} is not set or is None")
# ValueError: Environment variable POSTGRES_PASSWORD is not set or is None

# %% [markdown]
# # NR CQI Processing

# %%
from nr_cqi_level_processor import (
    populate_nr_cqi_metrics_daily,
    get_last_date_nr_cqi_metrics_daily,
    get_last_date_nr_cqi_daily
)
from datetime import datetime, timedelta
"""
Main execution block for populating nr CQI metrics daily table.
"""
print("nr CQI Level Processor - Full Database Population")

try:
    # Get date ranges
    last_processed_date = get_last_date_nr_cqi_metrics_daily()
    latest_available_date = get_last_date_nr_cqi_daily()
    
    print(f"Last processed date in nr_cqi_metrics_daily: {last_processed_date}")
    print(f"Latest available date in nr_cqi_daily: {latest_available_date}")
    
    # Determine date range for processing
    if last_processed_date is None:
        print("No data found in nr_cqi_metrics_daily table. Starting from earliest available data.")
        # If no processed data exists, we'll start from a reasonable date
        # You might want to adjust this based on your data availability
        min_date = "2024-01-01"  # Adjust this to your earliest desired date
    else:
        # Start from the day after the last processed date
        last_date_obj = datetime.strptime(str(last_processed_date), '%Y-%m-%d')
        next_date_obj = last_date_obj + timedelta(days=1)
        min_date = next_date_obj.strftime('%Y-%m-%d')
    
    if latest_available_date is None:
        print("No data found in nr_cqi_daily table. Cannot process.")
        exit()
    
    max_date = str(latest_available_date)
    
    print(f"Processing date range: {min_date} to {max_date}")
    
    # Check if there's new data to process
    if min_date <= max_date:
        print(f"Starting population of nr_cqi_metrics_daily...")
        print(f"This will process all hierarchical levels: network, region, province, municipality, site")
        
        # Populate the database with all hierarchical levels
        populate_nr_cqi_metrics_daily(min_date, max_date)
        
        print("Processing completed successfully!")
        print(f"Data populated for all hierarchical levels from {min_date} to {max_date}")

        # Verify the update
        new_last_processed_date = get_last_date_nr_cqi_metrics_daily()
        print(f"New last processed date: {new_last_processed_date}")
        
    else:
        print("No new data to process. Database is up to date.")
        
except Exception as e:
    print(f"Error during execution: {e}")
    
    import traceback
    traceback.print_exc()
# Out:
# nr CQI Level Processor - Full Database Population
# Last processed date in nr_cqi_metrics_daily: None
# Latest available date in nr_cqi_daily: 2025-08-10
# No data found in nr_cqi_metrics_daily table. Starting from earliest available data.
# Processing date range: 2024-01-01 to 2025-08-10
# Starting population of nr_cqi_metrics_daily...
# This will process all hierarchical levels: network, region, province, municipality, site
# Processing NR (5G) CQI metrics for date range: 2024-01-01 to 2025-08-10
# Deleting existing records for date range...
# Processing Level 1/6: network
# Retrieved 587 rows for network level
# Processing 587 rows in 1 chunks of 1000
#     Starting batch insertion: 587 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 85.2%
#     ✓ Batch 2/2: 87 rows inserted. Progress: 100.0%
#     Completed! 587 rows inserted successfully.
#   ✓ Chunk 1/1: 587 rows processed. Progress: 100.0%
# ✓ Successfully populated 587 records for network level
# Processing Level 2/6: region
# Retrieved 2935 rows for region level
# Processing 2,935 rows in 3 chunks of 1000
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 1/3: 1,000 rows processed. Progress: 34.1%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 2/3: 1,000 rows processed. Progress: 68.1%
#     Starting batch insertion: 935 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 53.5%
#     ✓ Batch 2/2: 435 rows inserted. Progress: 100.0%
#     Completed! 935 rows inserted successfully.
#   ✓ Chunk 3/3: 935 rows processed. Progress: 100.0%
# ✓ Successfully populated 2935 records for region level
# Processing Level 3/6: province
# Retrieved 13069 rows for province level
# Processing 13,069 rows in 14 chunks of 1000
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 1/14: 1,000 rows processed. Progress: 7.7%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 2/14: 1,000 rows processed. Progress: 15.3%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 3/14: 1,000 rows processed. Progress: 23.0%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 4/14: 1,000 rows processed. Progress: 30.6%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 5/14: 1,000 rows processed. Progress: 38.3%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 6/14: 1,000 rows processed. Progress: 45.9%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 7/14: 1,000 rows processed. Progress: 53.6%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 8/14: 1,000 rows processed. Progress: 61.2%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 9/14: 1,000 rows processed. Progress: 68.9%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 10/14: 1,000 rows processed. Progress: 76.5%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 11/14: 1,000 rows processed. Progress: 84.2%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 12/14: 1,000 rows processed. Progress: 91.8%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 13/14: 1,000 rows processed. Progress: 99.5%
#     Starting batch insertion: 69 rows in 1 batches
#     ✓ Batch 1/1: 69 rows inserted. Progress: 100.0%
#     Completed! 69 rows inserted successfully.
#   ✓ Chunk 14/14: 69 rows processed. Progress: 100.0%
# ✓ Successfully populated 13069 records for province level
# Processing Level 4/6: municipality
# Retrieved 63399 rows for municipality level
# Processing 63,399 rows in 64 chunks of 1000
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 1/64: 1,000 rows processed. Progress: 1.6%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 2/64: 1,000 rows processed. Progress: 3.2%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 3/64: 1,000 rows processed. Progress: 4.7%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 4/64: 1,000 rows processed. Progress: 6.3%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 5/64: 1,000 rows processed. Progress: 7.9%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 6/64: 1,000 rows processed. Progress: 9.5%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 7/64: 1,000 rows processed. Progress: 11.0%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 8/64: 1,000 rows processed. Progress: 12.6%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 9/64: 1,000 rows processed. Progress: 14.2%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 10/64: 1,000 rows processed. Progress: 15.8%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 11/64: 1,000 rows processed. Progress: 17.4%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 12/64: 1,000 rows processed. Progress: 18.9%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 13/64: 1,000 rows processed. Progress: 20.5%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 14/64: 1,000 rows processed. Progress: 22.1%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 15/64: 1,000 rows processed. Progress: 23.7%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 16/64: 1,000 rows processed. Progress: 25.2%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 17/64: 1,000 rows processed. Progress: 26.8%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 18/64: 1,000 rows processed. Progress: 28.4%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 19/64: 1,000 rows processed. Progress: 30.0%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 20/64: 1,000 rows processed. Progress: 31.5%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 21/64: 1,000 rows processed. Progress: 33.1%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 22/64: 1,000 rows processed. Progress: 34.7%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 23/64: 1,000 rows processed. Progress: 36.3%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 24/64: 1,000 rows processed. Progress: 37.9%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 25/64: 1,000 rows processed. Progress: 39.4%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 26/64: 1,000 rows processed. Progress: 41.0%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 27/64: 1,000 rows processed. Progress: 42.6%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 28/64: 1,000 rows processed. Progress: 44.2%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 29/64: 1,000 rows processed. Progress: 45.7%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 30/64: 1,000 rows processed. Progress: 47.3%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 31/64: 1,000 rows processed. Progress: 48.9%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 32/64: 1,000 rows processed. Progress: 50.5%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 33/64: 1,000 rows processed. Progress: 52.1%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 34/64: 1,000 rows processed. Progress: 53.6%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 35/64: 1,000 rows processed. Progress: 55.2%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 36/64: 1,000 rows processed. Progress: 56.8%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 37/64: 1,000 rows processed. Progress: 58.4%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 38/64: 1,000 rows processed. Progress: 59.9%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 39/64: 1,000 rows processed. Progress: 61.5%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 40/64: 1,000 rows processed. Progress: 63.1%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 41/64: 1,000 rows processed. Progress: 64.7%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 42/64: 1,000 rows processed. Progress: 66.2%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 43/64: 1,000 rows processed. Progress: 67.8%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 44/64: 1,000 rows processed. Progress: 69.4%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 45/64: 1,000 rows processed. Progress: 71.0%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 46/64: 1,000 rows processed. Progress: 72.6%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 47/64: 1,000 rows processed. Progress: 74.1%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 48/64: 1,000 rows processed. Progress: 75.7%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 49/64: 1,000 rows processed. Progress: 77.3%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 50/64: 1,000 rows processed. Progress: 78.9%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 51/64: 1,000 rows processed. Progress: 80.4%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 52/64: 1,000 rows processed. Progress: 82.0%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 53/64: 1,000 rows processed. Progress: 83.6%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 54/64: 1,000 rows processed. Progress: 85.2%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 55/64: 1,000 rows processed. Progress: 86.8%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 56/64: 1,000 rows processed. Progress: 88.3%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 57/64: 1,000 rows processed. Progress: 89.9%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 58/64: 1,000 rows processed. Progress: 91.5%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 59/64: 1,000 rows processed. Progress: 93.1%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 60/64: 1,000 rows processed. Progress: 94.6%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 61/64: 1,000 rows processed. Progress: 96.2%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 62/64: 1,000 rows processed. Progress: 97.8%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 63/64: 1,000 rows processed. Progress: 99.4%
#     Starting batch insertion: 399 rows in 1 batches
#     ✓ Batch 1/1: 399 rows inserted. Progress: 100.0%
#     Completed! 399 rows inserted successfully.
#   ✓ Chunk 64/64: 399 rows processed. Progress: 100.0%
# ✓ Successfully populated 63399 records for municipality level
# Processing Level 5/6: city
# Retrieved 69003 rows for city level
# Processing 69,003 rows in 70 chunks of 1000
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 1/70: 1,000 rows processed. Progress: 1.4%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 2/70: 1,000 rows processed. Progress: 2.9%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 3/70: 1,000 rows processed. Progress: 4.3%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 4/70: 1,000 rows processed. Progress: 5.8%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 5/70: 1,000 rows processed. Progress: 7.2%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 6/70: 1,000 rows processed. Progress: 8.7%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 7/70: 1,000 rows processed. Progress: 10.1%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 8/70: 1,000 rows processed. Progress: 11.6%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 9/70: 1,000 rows processed. Progress: 13.0%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 10/70: 1,000 rows processed. Progress: 14.5%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 11/70: 1,000 rows processed. Progress: 15.9%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 12/70: 1,000 rows processed. Progress: 17.4%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 13/70: 1,000 rows processed. Progress: 18.8%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 14/70: 1,000 rows processed. Progress: 20.3%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 15/70: 1,000 rows processed. Progress: 21.7%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 16/70: 1,000 rows processed. Progress: 23.2%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 17/70: 1,000 rows processed. Progress: 24.6%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 18/70: 1,000 rows processed. Progress: 26.1%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 19/70: 1,000 rows processed. Progress: 27.5%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 20/70: 1,000 rows processed. Progress: 29.0%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 21/70: 1,000 rows processed. Progress: 30.4%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 22/70: 1,000 rows processed. Progress: 31.9%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 23/70: 1,000 rows processed. Progress: 33.3%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 24/70: 1,000 rows processed. Progress: 34.8%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 25/70: 1,000 rows processed. Progress: 36.2%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 26/70: 1,000 rows processed. Progress: 37.7%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 27/70: 1,000 rows processed. Progress: 39.1%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 28/70: 1,000 rows processed. Progress: 40.6%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 29/70: 1,000 rows processed. Progress: 42.0%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 30/70: 1,000 rows processed. Progress: 43.5%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 31/70: 1,000 rows processed. Progress: 44.9%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 32/70: 1,000 rows processed. Progress: 46.4%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 33/70: 1,000 rows processed. Progress: 47.8%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 34/70: 1,000 rows processed. Progress: 49.3%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 35/70: 1,000 rows processed. Progress: 50.7%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 36/70: 1,000 rows processed. Progress: 52.2%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 37/70: 1,000 rows processed. Progress: 53.6%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 38/70: 1,000 rows processed. Progress: 55.1%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 39/70: 1,000 rows processed. Progress: 56.5%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 40/70: 1,000 rows processed. Progress: 58.0%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 41/70: 1,000 rows processed. Progress: 59.4%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 42/70: 1,000 rows processed. Progress: 60.9%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 43/70: 1,000 rows processed. Progress: 62.3%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 44/70: 1,000 rows processed. Progress: 63.8%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 45/70: 1,000 rows processed. Progress: 65.2%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 46/70: 1,000 rows processed. Progress: 66.7%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 47/70: 1,000 rows processed. Progress: 68.1%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 48/70: 1,000 rows processed. Progress: 69.6%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 49/70: 1,000 rows processed. Progress: 71.0%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 50/70: 1,000 rows processed. Progress: 72.5%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 51/70: 1,000 rows processed. Progress: 73.9%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 52/70: 1,000 rows processed. Progress: 75.4%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 53/70: 1,000 rows processed. Progress: 76.8%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 54/70: 1,000 rows processed. Progress: 78.3%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 55/70: 1,000 rows processed. Progress: 79.7%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 56/70: 1,000 rows processed. Progress: 81.2%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 57/70: 1,000 rows processed. Progress: 82.6%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 58/70: 1,000 rows processed. Progress: 84.1%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 59/70: 1,000 rows processed. Progress: 85.5%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 60/70: 1,000 rows processed. Progress: 87.0%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 61/70: 1,000 rows processed. Progress: 88.4%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 62/70: 1,000 rows processed. Progress: 89.9%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 63/70: 1,000 rows processed. Progress: 91.3%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 64/70: 1,000 rows processed. Progress: 92.7%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 65/70: 1,000 rows processed. Progress: 94.2%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 66/70: 1,000 rows processed. Progress: 95.6%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 67/70: 1,000 rows processed. Progress: 97.1%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 68/70: 1,000 rows processed. Progress: 98.5%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 69/70: 1,000 rows processed. Progress: 100.0%
#     Starting batch insertion: 3 rows in 1 batches
#     ✓ Batch 1/1: 3 rows inserted. Progress: 100.0%
#     Completed! 3 rows inserted successfully.
#   ✓ Chunk 70/70: 3 rows processed. Progress: 100.0%
# ✓ Successfully populated 69003 records for city level
# Processing Level 6/6: site
# Retrieved 1109674 rows for site level
# Processing 1,109,674 rows in 1110 chunks of 1000
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 1/1110: 1,000 rows processed. Progress: 0.1%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 2/1110: 1,000 rows processed. Progress: 0.2%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 3/1110: 1,000 rows processed. Progress: 0.3%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 4/1110: 1,000 rows processed. Progress: 0.4%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 5/1110: 1,000 rows processed. Progress: 0.5%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 6/1110: 1,000 rows processed. Progress: 0.5%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 7/1110: 1,000 rows processed. Progress: 0.6%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 8/1110: 1,000 rows processed. Progress: 0.7%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 9/1110: 1,000 rows processed. Progress: 0.8%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 10/1110: 1,000 rows processed. Progress: 0.9%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 11/1110: 1,000 rows processed. Progress: 1.0%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 12/1110: 1,000 rows processed. Progress: 1.1%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 13/1110: 1,000 rows processed. Progress: 1.2%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 14/1110: 1,000 rows processed. Progress: 1.3%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 15/1110: 1,000 rows processed. Progress: 1.4%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 16/1110: 1,000 rows processed. Progress: 1.4%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 17/1110: 1,000 rows processed. Progress: 1.5%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 18/1110: 1,000 rows processed. Progress: 1.6%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 19/1110: 1,000 rows processed. Progress: 1.7%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 20/1110: 1,000 rows processed. Progress: 1.8%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 21/1110: 1,000 rows processed. Progress: 1.9%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 22/1110: 1,000 rows processed. Progress: 2.0%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 23/1110: 1,000 rows processed. Progress: 2.1%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 24/1110: 1,000 rows processed. Progress: 2.2%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 25/1110: 1,000 rows processed. Progress: 2.3%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
# ...
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 1052/1110: 1,000 rows processed. Progress: 94.8%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 1053/1110: 1,000 rows processed. Progress: 94.9%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 1054/1110: 1,000 rows processed. Progress: 95.0%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 1055/1110: 1,000 rows processed. Progress: 95.1%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 1056/1110: 1,000 rows processed. Progress: 95.2%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 1057/1110: 1,000 rows processed. Progress: 95.3%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 1058/1110: 1,000 rows processed. Progress: 95.3%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 1059/1110: 1,000 rows processed. Progress: 95.4%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 1060/1110: 1,000 rows processed. Progress: 95.5%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 1061/1110: 1,000 rows processed. Progress: 95.6%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 1062/1110: 1,000 rows processed. Progress: 95.7%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 1063/1110: 1,000 rows processed. Progress: 95.8%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 1064/1110: 1,000 rows processed. Progress: 95.9%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 1065/1110: 1,000 rows processed. Progress: 96.0%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 1066/1110: 1,000 rows processed. Progress: 96.1%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 1067/1110: 1,000 rows processed. Progress: 96.2%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 1068/1110: 1,000 rows processed. Progress: 96.2%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 1069/1110: 1,000 rows processed. Progress: 96.3%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 1070/1110: 1,000 rows processed. Progress: 96.4%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 1071/1110: 1,000 rows processed. Progress: 96.5%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 1072/1110: 1,000 rows processed. Progress: 96.6%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 1073/1110: 1,000 rows processed. Progress: 96.7%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 1074/1110: 1,000 rows processed. Progress: 96.8%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 1075/1110: 1,000 rows processed. Progress: 96.9%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 1076/1110: 1,000 rows processed. Progress: 97.0%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 1077/1110: 1,000 rows processed. Progress: 97.1%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 1078/1110: 1,000 rows processed. Progress: 97.1%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 1079/1110: 1,000 rows processed. Progress: 97.2%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 1080/1110: 1,000 rows processed. Progress: 97.3%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 1081/1110: 1,000 rows processed. Progress: 97.4%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 1082/1110: 1,000 rows processed. Progress: 97.5%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 1083/1110: 1,000 rows processed. Progress: 97.6%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 1084/1110: 1,000 rows processed. Progress: 97.7%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 1085/1110: 1,000 rows processed. Progress: 97.8%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 1086/1110: 1,000 rows processed. Progress: 97.9%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 1087/1110: 1,000 rows processed. Progress: 98.0%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 1088/1110: 1,000 rows processed. Progress: 98.0%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 1089/1110: 1,000 rows processed. Progress: 98.1%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 1090/1110: 1,000 rows processed. Progress: 98.2%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 1091/1110: 1,000 rows processed. Progress: 98.3%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 1092/1110: 1,000 rows processed. Progress: 98.4%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 1093/1110: 1,000 rows processed. Progress: 98.5%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 1094/1110: 1,000 rows processed. Progress: 98.6%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 1095/1110: 1,000 rows processed. Progress: 98.7%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 1096/1110: 1,000 rows processed. Progress: 98.8%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 1097/1110: 1,000 rows processed. Progress: 98.9%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 1098/1110: 1,000 rows processed. Progress: 98.9%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 1099/1110: 1,000 rows processed. Progress: 99.0%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 1100/1110: 1,000 rows processed. Progress: 99.1%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 1101/1110: 1,000 rows processed. Progress: 99.2%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 1102/1110: 1,000 rows processed. Progress: 99.3%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 1103/1110: 1,000 rows processed. Progress: 99.4%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 1104/1110: 1,000 rows processed. Progress: 99.5%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 1105/1110: 1,000 rows processed. Progress: 99.6%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 1106/1110: 1,000 rows processed. Progress: 99.7%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 1107/1110: 1,000 rows processed. Progress: 99.8%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 1108/1110: 1,000 rows processed. Progress: 99.8%
#     Starting batch insertion: 1,000 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 50.0%
#     ✓ Batch 2/2: 500 rows inserted. Progress: 100.0%
#     Completed! 1,000 rows inserted successfully.
#   ✓ Chunk 1109/1110: 1,000 rows processed. Progress: 99.9%
#     Starting batch insertion: 674 rows in 2 batches
#     ✓ Batch 1/2: 500 rows inserted. Progress: 74.2%
#     ✓ Batch 2/2: 174 rows inserted. Progress: 100.0%
#     Completed! 674 rows inserted successfully.
#   ✓ Chunk 1110/1110: 674 rows processed. Progress: 100.0%
# ✓ Successfully populated 1109674 records for site level
# Processing completed successfully!
# Data populated for all hierarchical levels from 2024-01-01 to 2025-08-10
# New last processed date: 2025-08-10
