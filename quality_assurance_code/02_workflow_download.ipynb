# %% [markdown]
# # Download Workflow
#
# Sync data from Google Drive to local directories.

# %% [markdown]
# ## Setup

# %%
import os
from dotenv import load_dotenv
from downloader import sync_drive_to_pc

# Load environment variables
load_dotenv()
ROOT_DIRECTORY = os.getenv("ROOT_DIRECTORY")

# Path to credentials
credentials_path = os.path.join(
    ROOT_DIRECTORY,
    "input",
    "client_secret_417341470393-kqf1bgogf8vgkmi6jgsf7absjv2nolrk.apps.googleusercontent.com.json"
)

# %% [markdown]
# ## Sync Configuration

# %%
# Define sync configuration
sync_config = [
    {
        "pc_path": "input/daily_3g_cqi_site",
        "root_folder_id": "1rDdcglI3yKZMsS-ucSXFyZbT-X3Xt2ji",
        "subfolder_name": "daily_3g_cqi_site",
        "mode": "delta"
    },
    {
        "pc_path": "input/daily_lte_cqi_site",
        "root_folder_id": "1rDdcglI3yKZMsS-ucSXFyZbT-X3Xt2ji",
        "subfolder_name": "daily_lte_cqi_site",
        "mode": "delta"
    },
    {
        "pc_path": "input/daily_5g_cqi_site",
        "root_folder_id": "1rDdcglI3yKZMsS-ucSXFyZbT-X3Xt2ji",
        "subfolder_name": "daily_5g_cqi_site",
        "mode": "delta"
    },
    {
        "pc_path": "input/daily_volte_cqi_site/samsung",
        "root_folder_id": "1LJiBEevfop3hdRIAD8LOgLNc23ZfwmUD",
        "subfolder_name": "samsung",
        "mode": "delta"
    },
    {
        "pc_path": "input/daily_volte_cqi_site/huawei",
        "root_folder_id": "1LJiBEevfop3hdRIAD8LOgLNc23ZfwmUD",
        "subfolder_name": "huawei",
        "mode": "delta"
    },
    {
        "pc_path": "input/daily_volte_cqi_site/ericsson",
        "root_folder_id": "1LJiBEevfop3hdRIAD8LOgLNc23ZfwmUD",
        "subfolder_name": "ericsson",
        "mode": "delta"
    },
    {
        "pc_path": "input/daily_volte_cqi_site/nokia",
        "root_folder_id": "1LJiBEevfop3hdRIAD8LOgLNc23ZfwmUD",
        "subfolder_name": "nokia",
        "mode": "delta"
    },
    {
        "pc_path": "input/master_cells/last",
        "root_folder_id": "1rDdcglI3yKZMsS-ucSXFyZbT-X3Xt2ji",
        "subfolder_name": "master_cell",
        "mode": "replace",
        "skip_file_list": ["master_cell.rar"]
    },
    {
        "pc_path": "input/ept",
        "root_folder_id": "1rDdcglI3yKZMsS-ucSXFyZbT-X3Xt2ji",
        "subfolder_name": "ept",
        "mode": "replace",
        "skip_file_list": ["EPT.rar"]
    },
    {
        "pc_path": "input/daily_lte_traffic_cell/samsung",
        "root_folder_id": "1KYXdd9wQI0qylOYwqF-ONF6KPckKeHJD",
        "subfolder_name": "samsung",
        "mode": "delta"
    },
    {
        "pc_path": "input/daily_lte_traffic_cell/huawei",
        "root_folder_id": "1KYXdd9wQI0qylOYwqF-ONF6KPckKeHJD",
        "subfolder_name": "huawei",
        "mode": "delta"
    },
    {
        "pc_path": "input/daily_lte_traffic_cell/ericsson",
        "root_folder_id": "1KYXdd9wQI0qylOYwqF-ONF6KPckKeHJD",
        "subfolder_name": "ericsson",
        "mode": "delta"
    },
    {
        "pc_path": "input/daily_lte_traffic_cell/nokia",
        "root_folder_id": "1KYXdd9wQI0qylOYwqF-ONF6KPckKeHJD",
        "subfolder_name": "nokia",
        "mode": "delta"
    },
    {
        "pc_path": "input/daily_umts_traffic_cell/nokia",
        "root_folder_id": "1wE7JqBb_DWqGXH-q0PENlF0BxoZthIrc",
        "subfolder_name": "nokia",
        "mode": "delta"
    },
    {
        "pc_path": "input/daily_umts_traffic_cell/huawei",
        "root_folder_id": "1wE7JqBb_DWqGXH-q0PENlF0BxoZthIrc",
        "subfolder_name": "huawei",
        "mode": "delta"
    },
    {
        "pc_path": "input/daily_umts_traffic_cell/ericsson",
        "root_folder_id": "1wE7JqBb_DWqGXH-q0PENlF0BxoZthIrc",
        "subfolder_name": "ericsson",
        "mode": "delta"
    },
    
]

# %% [markdown]
# ## Execute Sync

# %%
# Run sync
sync_drive_to_pc(credentials_path=credentials_path, sync_config=sync_config)
# Out:
# Your browser has been opened to visit:
#
#     https://accounts.google.com/o/oauth2/auth?client_id=417341470393-kqf1bgogf8vgkmi6jgsf7absjv2nolrk.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A8080%2F&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&access_type=online&response_type=code
#
# Authentication successful.
#
# 🔍 Looking for subfolder: daily_3g_cqi_site
# 📁 Syncing: C:\python\quality_assurance\input/daily_3g_cqi_site ← daily_3g_cqi_site [mode: delta]
# 🧹 Deleting last alphabetical file: daily_3g_cqi_site_2025_w31.zip
# ⬇ Downloading: daily_3g_cqi_site_2025_w31.zip
# ✅ Done: C:\python\quality_assurance\input/daily_3g_cqi_site
#
# 🔍 Looking for subfolder: daily_lte_cqi_site
# 📁 Syncing: C:\python\quality_assurance\input/daily_lte_cqi_site ← daily_lte_cqi_site [mode: delta]
# 🧹 Deleting last alphabetical file: daily_lte_cqi_site_2025_w31.zip
# ⬇ Downloading: daily_lte_cqi_site_2025_w31.zip
# ✅ Done: C:\python\quality_assurance\input/daily_lte_cqi_site
#
# ...
