# %%
from insert_db_lte_cell_period import lte_cell_period_process
from insert_db_lte_cell_change import lte_cell_change_process

lte_cell_period_process()
lte_cell_change_process()
# Out:
# ...
# LTE CELL TRAFFIC PERIOD UNIFIED PROCESSING
# ...
# Processing all data in lte_cell_traffic_daily table
# Period: p3 (3 consecutive days)
# Database: localhost:5432/quality_assurance
# Username: postgres
# Root Directory: C:\python\cell_change_evolution
# Started at: 2025-08-04 19:34:25
# ...
#
# STEP 1: Truncating table...
# ----------------------------------------
# Truncating lte_cell_traffic_period table...
# Table truncated successfully
#
# STEP 2: Processing init_dates...
# ----------------------------------------
# Processing init_date detection (p3 = 3 consecutive days)
# Processing all data in lte_cell_traffic_daily table
# Algorithm: Window function with ROW_NUMBER()
#
# Init_date processing completed successfully
# Rows affected: 127,825
# Approach: INSERT new calculations
#
# STEP 3: Processing end_dates...
# ----------------------------------------
# Processing end_date detection (p3 = 3 consecutive days)
# Processing all data in lte_cell_traffic_daily table
# ...

# %%
from insert_db_umts_cell_period import umts_cell_period_process
from insert_db_umts_cell_change import umts_cell_change_process

umts_cell_period_process()
umts_cell_change_process()
# Out:
# ...
# UMTS CELL TRAFFIC PERIOD UNIFIED PROCESSING
# ...
# Processing all data in umts_cell_traffic_daily table
# Period: p3 (3 consecutive days)
# Database: localhost:5432/quality_assurance
# Username: postgres
# Root Directory: C:\python\cell_change_evolution
# Started at: 2025-08-01 16:04:48
# ...
#
# STEP 1: Truncating table...
# ----------------------------------------
# Truncating umts_cell_traffic_period table...
# Table truncated successfully
#
# STEP 2: Processing init_dates...
# ----------------------------------------
# Processing init_date detection (p3 = 3 consecutive days)
# Processing all data in umts_cell_traffic_daily table
# Algorithm: Window function with ROW_NUMBER()
#
# Init_date processing completed successfully
# Rows affected: 104,456
# Approach: INSERT new calculations
#
# STEP 3: Processing end_dates...
# ----------------------------------------
# Processing end_date detection (p3 = 3 consecutive days)
# Processing all data in umts_cell_traffic_daily table
# ...
